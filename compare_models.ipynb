# %% [markdown]
# # Comparing models

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
dist1 = np.load('fixed1.npz')
dist2 = np.load('fixed2.npz')
scores1 = np.asarray([dist1['scores']]).flatten()
scores2 = np.asarray([dist2['scores']]).flatten()
scores1.sort()
scores2.sort()
results = np.vstack([scores1, scores2])
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (2, 1000)

# %%
for i in range(2):
    plt.plot(results[i])
plt.legend(['Run 1','Run 2'])

# %%
for i in range(2):
    plt.plot(logresults[i])
plt.legend(['Run 1','Run 2'])

# %%
# KS stats for sampling error for n=1000.
# Sampling from the same distribution gives
# a k-stat of 0.032 and p of 0.68
# 1000 samples should have enough stat power
# to resolve small differences in performance
stats.ks_2samp(logresults[0], logresults[1])
# Out:
# Ks_2sampResult(statistic=0.03199999999999997, pvalue=0.6785103823828913)

# %% [markdown]
# # Initial training
# Evaluate trained models by comparing their performance.
# First training for 100 epochs on 10 fixed order mcts games.

# %% [markdown]
# ### From early midgame

# %%
results = []
for i in [0, 49, 99]:
    dist = np.load('0_10_epox100_lr0.1_e{}.npz'.format(i))
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)￼
results = []
for i in [0, 49, 99]:
    dist = np.load('0_10_epox100_lr0.1_e{}.npz'.format(i))
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
(3, 1000)
In [3]:
￼
for i in range(len(results)):
    plt.plot(results[i])
plt.legend([0, 49, 99])
Out[3]:
<matplotlib.legend.Legend at 0x1e72dd532e8>
￼
In [4]:
￼
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend([0, 49, 99])
Out[4]:
<matplotlib.legend.Legend at 0x1e72ddcfe80>
￼
In [5]:

print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (3, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend([0, 49, 99])

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend([0, 49, 99])

# %%
print(stats.ks_2samp(logresults[0], logresults[2]))
print(stats.ks_2samp(logresults[1], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.504, pvalue=5.587863354159026e-112)
# Ks_2sampResult(statistic=0.07, pvalue=0.014097547738750731)

# %% [markdown]
# ### From start

# %%
results = []
for i in [0, 49, 99]:
    dist = np.load('0_10_epox100_lr0.1_e{}_start.npz'.format(i))
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (3, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend([0, 49, 99])

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend([0, 49, 99])

# %%
print(stats.ks_2samp(logresults[0], logresults[2]))
print(stats.ks_2samp(logresults[1], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.304, pvalue=5.194893269078377e-41)
# Ks_2sampResult(statistic=0.07400000000000001, pvalue=0.007873852459750459)

# %% [markdown]
# ### Compared with fixed
# Trained model performs better than random, but not better than fixed order

# %%
dist1 = np.load('fixed1.npz')
dist2 = np.load('0_10_epox100_lr0.1_e{}_start.npz'.format(99))
scores1 = np.asarray([dist1['scores']]).flatten()
scores2 = np.asarray([dist2['scores']]).flatten()
scores1.sort()
scores2.sort()
results = np.vstack([scores1, scores2])
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (2, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(['fixed', '99'])

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(['fixed','99'])

# %%
print(stats.ks_2samp(logresults[0], logresults[1]))
# Out:
# Ks_2sampResult(statistic=0.358, pvalue=1.0386480044592873e-56)

# %% [markdown]
# ## New training comparisons
# * 0-9: Fixed
# * 10-19: `0_10_epox100_lr0.1_e99`

# %%
results = []
names = ['0_10_epox100_lr0.1_e99.npz',
        '10_20_epox100_lr0.1_e99.npz',
         '0_20_epox100_lr0.1_e99.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (3, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %%
print(stats.ks_2samp(logresults[0], logresults[2]))
print(stats.ks_2samp(logresults[1], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.11399999999999999, pvalue=3.923743560962539e-06)
# Ks_2sampResult(statistic=0.038000000000000034, pvalue=0.4585797916571728)

# %% [markdown]
# 0_10 trained is strongest, statistically significant compared to 10_20 or 0_20 trained.

# %% [markdown]
# ### Pretraining

# %%
results = []
names = ['0_10_epox100_lr0.1_e99.npz',
        '10_20_epox100_lr0.1_e99.npz',
        '10_20_epox100_lr0.1pre_e99.npz',
        '10_20_epox100_lr0.01pre_e99.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (4, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %%
print(stats.ks_2samp(logresults[0], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.133, pvalue=3.40973448751773e-08)

# %% [markdown]
# 0_10 trained is still strongest, statistically significant compared to pretrained on 0_10 then trained on 10_20.
# The lower loss of the lr=0.01 pretrained model does not translate to better playing strength.

# %% [markdown]
# ### vs Fixed
# None of these are better than Fixed, so I should use Fixed to simulate games until the network outperforms.

# %%
results = []
names = ['0_10_epox100_lr0.1_e99.npz',
        'fixed1.npz',
        'fixed2.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (3, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %%
print(stats.ks_2samp(logresults[0], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.475, pvalue=1.6422924177984775e-99)

# %% [markdown]
# ### 2019-06-10 Less epochs
# Performance peaks around 10-20 epochs, which corresponds to when the model starts to overfit and val loss goes up.
# Still not better than fixed.

# %%
results = []
names = ['20190610/5_20_epox30_lr0.1_e{}.npz'.format(i) \
         for i in [0, 9, 19, 29]]
names.extend(['fixed1.npz', 'fixed2.npz'])
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (6, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %%
print(np.mean(results, axis=1))
print(np.mean(logresults, axis=1))
print('Here score and logscore have different winners (10 vs 20 epochs)')
# Out:
# [ 445.112 1418.224 1482.46  1294.16  2323.836 2295.112]
# [2.40595139 3.01659746 3.00801683 2.93668946 3.30919566 3.30314662]
# Here score and logscore have different winners (10 vs 20 epochs)

# %%
print(stats.ks_2samp(logresults[1], logresults[2]))
print(stats.ks_2samp(logresults[1], logresults[3]))
# Out:
# Ks_2sampResult(statistic=0.05900000000000005, pvalue=0.059197199379241984)
# Ks_2sampResult(statistic=0.11700000000000005, pvalue=1.9469841454622735e-06)

# %% [markdown]
# ### 2019-06-10 More Data
# Performance improves given more training data.

# %%
results = []
names = ['20190610/5_30_epox60_lr0.1_e{}.npz'.format(i) \
         for i in [9, 19, 29, 39]]
names.extend(['fixed1.npz', 'fixed2.npz'])
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (6, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %% [markdown]
# Trained network may play better than fixed at high scores (complex and filled boards) since the curves cross over the fixed curve for the last 900 games.

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %%
print(np.mean(results, axis=1))
print(np.mean(logresults, axis=1))
print('I can train for longer and get better results with more data')
# Out:
# [1660.772 1905.176 1774.176 1277.352 2323.836 2295.112]
# [3.02442535 3.14896565 3.0806699  2.96831611 3.30919566 3.30314662]
# I can train for longer and get better results with more data

# %%
# Compare 5-30 with 5-20
results = []
names = ['20190610/5_20_epox30_lr0.1_e9.npz', 
         '20190610/5_30_epox60_lr0.1_e19.npz', 
         'fixed1.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (3, 1000)

# %%
plt.subplots(figsize=(12, 4))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()
print('Playing strength improved with more training games')
# Out:
# Playing strength improved with more training games

# %% [markdown]
# ## More games (40)

# %%
results = []
names = ['20190611/5_40_epox60_lr0.1_e{}.npz'.format(i) \
         for i in [9, 19, 29, 39]]
names.extend(['fixed1.npz', 'fixed2.npz'])
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (6, 1000)

# %%
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)

# %%
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)

# %% [markdown]
# Playing performance seems to lag validation curve: `e29` has best playing strength, but validation loss has already started to curve higher by epoch 30. Similar thing with 5-30 games and `e19` being stronger than `e9`. Perhaps I need to increase size of validation set to 10 games.

# %%
# Compare 40, 30, and 20
results = []
names = ['20190610/5_20_epox30_lr0.1_e9.npz', 
         '20190610/5_30_epox60_lr0.1_e19.npz',
         '20190611/5_40_epox60_lr0.1_e29.npz',
         'fixed1.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (4, 1000)

# %%
plt.subplots(figsize=(12, 4))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()
print('Playing strength is weaker for 35 games vs 25')
# Out:
# Playing strength is weaker for 35 games vs 25

# %%
print(stats.ks_2samp(logresults[1], logresults[2]))
# Out:
# Ks_2sampResult(statistic=0.061, pvalue=0.04644173907524361)

# %% [markdown]
# ## More games (50)
# 10 val, 40 train

# %%
results = []
names = ['20190611/10_50_epox60_lr0.1_e{}.npz'.format(i) \
         for i in [9, 19, 29, 39]]
names.extend(['fixed1.npz', 'fixed2.npz'])
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (6, 1000)

# %%
plt.subplots(figsize=(14, 5))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()

# %%
# Compare best of different training runs
results = []
names = ['20190610/5_30_epox60_lr0.1_e19.npz',
         '20190611/5_40_epox60_lr0.1_e29.npz',
         '20190611/10_50_epox60_lr0.1_e29.npz',
         'fixed1.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (4, 1000)

# %%
plt.subplots(figsize=(12, 4))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()
print('Playing strength of 40 is still slightly weaker than 25 but better than 35')
# Out:
# Playing strength of 40 is still slightly weaker than 25 but better than 35

# %%
print('No statistical significance')
print(stats.ks_2samp(logresults[0], logresults[2]))
print(stats.ks_2samp(logresults[1], logresults[2]))
# Out:
# No statistical significance
# Ks_2sampResult(statistic=0.05199999999999999, pvalue=0.12984378016123646)
# Ks_2sampResult(statistic=0.039000000000000035, pvalue=0.4253468503964972)

# %% [markdown]
# ## More games (60)
# 10 val, 50 train
#
# Later models (already starting to overfit) actually perform better.

# %%
results = []
names = ['20190614/10_60_epox60_lr0.1_e{}.npz'.format(i) \
         for i in [39, 49, 59]]
names.extend(['fixed1.npz', 'fixed2.npz'])
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (5, 1000)

# %%
plt.subplots(figsize=(14, 5))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()

# %%
# Compare best of different training runs
results = []
names = ['20190610/5_30_epox60_lr0.1_e19.npz',
         '20190611/10_50_epox60_lr0.1_e29.npz',
         '20190614/10_60_epox60_lr0.1_e49.npz',
         'fixed1.npz']
for name in names:
    dist = np.load(name)
    scores = np.asarray([dist['scores']]).flatten()
    scores.sort()
    results.append(scores)
results = np.vstack(results)
print(results.shape)
logresults = np.log10(results + 1)
# Out:
# (4, 1000)

# %%
plt.subplots(figsize=(12, 4))
plt.subplot(121)
for i in range(len(results)):
    plt.plot(results[i])
plt.legend(names)
plt.subplot(122)
for i in range(len(logresults)):
    plt.plot(logresults[i])
plt.legend(names)
plt.show()
print('10_60_e49 much stronger, especially late game')
# Out:
# 10_60_e49 much stronger, especially late game

# %%
print(stats.ks_2samp(logresults[2], logresults[0]))
print(stats.ks_2samp(logresults[2], logresults[-1]))
# Out:
# Ks_2sampResult(statistic=0.057, pvalue=0.07761108123267829)
# Ks_2sampResult(statistic=0.186, pvalue=1.5702401851850447e-15)
